# %%
# %load_ext autoreload
# %autoreload 2

import os, re, json, ast
from parallel_descriptions import send_message_to_gemini_async
from km_utils import get_ToCs
from coap_prompts import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Pipeline

# %%
ToCs = get_ToCs(base_path = 'coap_map')

ToC_sections = ToCs['ToC_sections']
ToC_chapters = ToCs['ToC_chapters']
ToC_articles_short_descriptions = ToCs['ToC_articles_short_descriptions']
ToC_articles_descriptions = ToCs['ToC_articles_descriptions']

# %%
user_query_ori = "что будет за дискредитацию армии рф?"
user_query = await get_perefrased_query(user_query_ori)
user_query = user_query['text_response']
user_query
# Out:
# '["Каковы последствия дискредитации Вооруженных сил Российской Федерации?", "Какие конкретные действия считаются дискредитацией?", "Какие меры наказания предусмотрены за дискредитацию?"]'

# %%
from datetime import datetime, timedelta
import google.generativeai as genai
import json, asyncio
from parallel_descriptions import RateLimiter

def split_dict_by_size(input_dict, size_limit=30000):
    """
    Splits a dictionary into multiple dictionaries, each as in a string equivalent not exceeding size_limit characters.
    """
    parts = []  # List to hold the resulting dictionaries
    current_part = {}  # Current dictionary part being filled
    current_size = 2  # Account for the empty dictionary braces '{}'

    for key, value in input_dict.items():
        # Estimate size of current item. Add 4 for ': ' and ', ' (the latter for all but the last item)
        item_size = len(repr(key)) + len(repr(value)) + 4
        if current_size + item_size > size_limit:
            # Add the current part to the list and start a new one
            parts.append(current_part)
            current_part = {key: value}
            current_size = 2 + item_size  # Reset size for the new part, including braces
        else:
            # Add item to the current part
            current_part[key] = value
            current_size += item_size

    # Add the final part if not empty
    if current_part:
        parts.append(current_part)

    return parts



async def get_chapter_navigation(user_query, ToC_chapters_chunks, rate_limiter):
    tasks = []
    for ToC_chunk in ToC_chapters_chunks:
        if isinstance(ToC_chunk, dict): 
            ToC_chunk = json.dumps(ToC_chunk, ensure_ascii=False)

        # ToC_chunk = json.dumps(ToC_chunk, ensure_ascii=False, indent=2)
        prompt = """ТЫ — AI-помощник, который для ответа на вопрос помогает находить главу и статью из КОАП РФ, чтобы более точно ответить на вопрос.
Тебе нужно выбрать несколько статей в которых может содержаться ответ или часть ответа. Выводи все потенциально полезные статьи.
Вот список глав со статьями:
<ToC_chapters>
{ToC_chapters}
</ToC_chapters>
Вот вопрос от юзера:
<query>{USER_QUERY}</query>
Выведи список с полнымми релевантных глав в порядке убывания важности с полным посимвольным совпадением как в приведеном списке <ToC_chapters>.
Формат вывода: ["Название главы 1", "Название главы 2"]
""".format(USER_QUERY=user_query, ToC_chapters=ToC_chunk)

        task = asyncio.create_task(send_message_to_gemini_async(user_input=prompt, rate_limiter=rate_limiter))
        tasks.append(task)
    
    descriptions = await asyncio.gather(*tasks)
    return descriptions

class RateLimiter:
    def __init__(self, calls_per_period, period=1.0):
        self.calls_per_period = calls_per_period
        self.period = timedelta(seconds=period)
        self.calls = []

    async def wait(self):
        now = datetime.now()
        
        while self.calls and now - self.calls[0] > self.period:
            self.calls.pop(0)
            
        if len(self.calls) >= self.calls_per_period:
            sleep_time = (self.period - (now - self.calls[0])).total_seconds()
            await asyncio.sleep(sleep_time)
            return await self.wait()

        self.calls.append(datetime.now())


rate_limiter = RateLimiter(5, 6)
section = 'Раздел II. Особенная часть'
ToC_chapters_chunks = split_dict_by_size(ToC_chapters[section], 30000)
await get_chapter_navigation(user_query, ToC_chapters_chunks, rate_limiter)
# Out:
# [{'text_response': '["Глава 20. Административные правонарушения, посягающие наобщественный порядок и общественную безопасность"]',
#   'input_tokens': total_tokens: 5472,
#   'output_tokens': total_tokens: 25},
#  {'text_response': '["Глава 5. Административные правонарушения, посягающие на праваграждан"]',
#   'input_tokens': total_tokens: 7423,
#   'output_tokens': total_tokens: 21},
#  {'text_response': '["Глава 13. Административные правонарушения в области связи иинформации"]',
#   'input_tokens': total_tokens: 6614,
#   'output_tokens': total_tokens: 19},
#  {'text_response': 'Этот вопрос не связан с темами, перечисленными в списке глав.',
#   'input_tokens': total_tokens: 6506,
#   'output_tokens': total_tokens: 16},
#  {'text_response': '["Глава 19. Административные правонарушения против порядка управления"]',
#   'input_tokens': total_tokens: 3261,
#   'output_tokens': total_tokens: 15}]

# %%
async def get_section_nagigation(USER_QUERY, ToC_sections):
    if isinstance(ToC_sections, dict):
        ToC_sections = json.dumps(ToC_sections, ensure_ascii=False, indent=2)

    prompt = """Вы — AI-помощник навигации, который помогает по вопросу от юзера находить пути к необходимой информации в КОАП РФ, чтобы точно ответить на вопрос.
Вам нужно выбрать 1 или несколько разделов первого уровня.
Вот список разделов с описаниями в формате json:
<map>
{ToC_sections}
</map>
Вот вопрос от юзера:
<query>{USER_QUERY}</query>
Выведите список JSON с путями навигации к соответствующей информации. Выводи только разделы.
Формат должен выглядеть так:
["Раздел 1", "Раздел 2"]
""".format(USER_QUERY=USER_QUERY, ToC_sections=ToC_sections)
    description = await send_message_to_gemini_async(prompt, attempt=1, max_attempts=10)
    return description


# async def get_chapter_nagigation(USER_QUERY, ToC_chapters):
#     if isinstance(ToC_chapters, dict):
#         ToC_chapters = json.dumps(ToC_chapters, ensure_ascii=False, indent=2)

#     prompt = """ТЫ — AI-помощник, который для ответа на вопрос помогает находить главу из КОАП РФ, чтобы более точно ответить на вопрос.
# Тебе нужно выбрать 1 или несколько глав в которых может содержаться ответ или часть ответа. Выводи все потенциально полезные главы, внутри глав будет содержатся много статей, некоторые из которых окажутся полезными.
# Вот список глав:
# <ToC_chapters>
# {ToC_chapters}
# </ToC_chapters>
# Вот вопрос от юзера:
# <query>{USER_QUERY}</query>
# Выведите список с полнымми названиями глав с полным посимвольным совпадением как в приведеном списке <ToC_chapters>.
# Формат должен выглядеть так:
# ["Глава 1", "Глава 2"]
# """.format(USER_QUERY=USER_QUERY, ToC_chapters=ToC_chapters)
#     description = await send_message_to_gemini_async(prompt, attempt=1, max_attempts=10)
#     return description


async def get_article_nagigation(USER_QUERY, articles):
    if isinstance(articles, dict):
        articles = json.dumps(articles, ensure_ascii=False, indent=2)

    prompt = """Вы — AI-помощник навигации, который помогает по вопросу от юзера находить пути к необходимой информации  в КОАП РФ, чтобы точно ответить на вопрос.
Вам нужно выбрать 1 или несколько статей. Старайся вывести все потенциально релевантные статьи.
Вот список статей с описаниями в формате json:
<map>
{articles}
</map>
Вот вопрос от юзера:
<query>{USER_QUERY}</query>
Выведите список JSON с путями навигации к соответствующей информации. Выводи полное название статьей.
Формат должен выглядеть так:
["Статья 1", "Статья 2"]
""".format(USER_QUERY=USER_QUERY, articles=articles)
    description = await send_message_to_gemini_async(prompt, attempt=1, max_attempts=10)
    return description


articles = []

# Chooes Sections
get_section_response = await get_section_nagigation(user_query, ToC_sections)
try: choosed_sections = ast.literal_eval(get_section_response['text_response'])
except: print(f'Section error: {get_section_response["text_response"]}')
# Chooes Chapters
for section in choosed_sections:
    print(section)
    # get_chapter_response = await get_chapter_nagigation(user_query, ToC_chapters[section])
    ToC_chapters_chunks = split_dict_by_size(ToC_chapters[section], 30000)
    descriptions = await get_chapter_navigation(user_query, ToC_chapters_chunks, rate_limiter)
    choosed_chapters = []
    for d in descriptions:
        try: text_response = ast.literal_eval(d['text_response'])
        except: print(f'Chapter error: {d["text_response"]}')
        if len(text_response) > 0:
            choosed_chapters.extend(text_response)
    
    # Chooes Articles
    for chapter in choosed_chapters:
        print(chapter)
        get_article_response = await get_article_nagigation(user_query, ToC_articles_short_descriptions[section][chapter])
        try: choosed_articles = ast.literal_eval(get_article_response['text_response'])
        except: print(f'Chapter error: {get_article_response["text_response"]}')

        for article in choosed_articles:
            print(article)
            article_text = nested_json['childs'][section]['childs'][chapter]['childs'][article]['content']
            articles.append({'section':section, 'chapter':chapter, 'article':article, 'article_text':article_text})

articles
# Out:
# Раздел II. Особенная часть
# Chapter error: Этот вопрос не связан с темами, перечисленными в списке глав.
# Глава 20. Административные правонарушения, посягающие наобщественный порядок и общественную безопасность
# Статья 20.3.3. Публичные действия, направленные на дискредитацию использования Вооруженных Сил Российской Федерации в целях защиты интересов Российской Федерации и ее граждан, поддержания международного мира и безопасности или исполнения государствен
# Глава 5. Административные правонарушения, посягающие на праваграждан
# Chapter error: В предоставленном тексте нет статей, касающихся публичных высказываний, которые могут быть расценены как дискредитация Вооруженных сил Российской Федерации.
# Статья 20.3.3. Публичные действия, направленные на дискредитацию использования Вооруженных Сил Российской Федерации в целях защиты интересов Российской Федерации и ее граждан, поддержания международного мира и безопасности или исполнения государствен
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[89], line 89
#      87         for article in choosed_articles:
#      88             print(article)
# ---> 89             article_text = nested_json['childs'][section]['childs'][chapter]['childs'][article]['content']
#      90             articles.append({'section':section, 'chapter':chapter, 'article':article, 'article_text':article_text})
#      92 articles
#
# KeyError: 'Статья 20.3.3. Публичные действия, направленные на дискредитацию использования Вооруженных Сил Российской Федерации в целях защиты интересов Российской Федерации и ее граждан, поддержания международного мира и безопасности или исполнения государствен'

# %%
async def get_final_response(USER_QUERY, context):
    prompt = """Ты профессиональный Юрист который отвечает на вопросы людей ориентируясь на статьи из КоАП РФ
Вот релевантная статья:
<article>
{context}
</article>
Вот вопрос:
<query>{USER_QUERY}</query>

Ответь нв вопрос, процитировав название статьи, раздел и главу. 
Если тебе не дали релевантную статью, попробуй ответить на вопрос, но скажи что "релевантная статья не найдена, попробуйте переформулировать вопрос".
Формат ответа:
<краткий ответ на вопрос пользователя>
<точный адрес статьи, включающий в себя название раздела, главы и название статьи>
""".format(USER_QUERY=USER_QUERY, context=context)
    description = await send_message_to_gemini_async(prompt, attempt=1, max_attempts=10)
    return description, prompt

get_article_response, prompt = await get_final_response(user_query, articles)
print(get_article_response['text_response'])
# Out:
# Публичные действия, направленные на дискредитацию использования Вооруженных Сил Российской Федерации влекут наложение административного штрафа.
# Раздел II. Особенная часть, Глава 20. Административные правонарушения, посягающие наобщественный порядок и общественную безопасность, Статья 20.3.3. Публичные действия, направленные на дискредитацию использования Вооруженных Сил Российской Федерации в целях защиты интересов Российской Федерации и ее граждан, поддержания международного мира и безопасности или исполнения государствен

# %%
# Out:
# Штраф за пересечение стоп-линии при красном сигнале светофора составляет 800 рублей.
# Раздел II. Особенная часть, Глава 12. Административные правонарушения в области дорожного движения, Статья 12.12. Проезд на запрещающий сигнал светофора или на запрещающий жест регулировщика

# %%
from pprint import pprint
pprint(prompt)
# Out:
# ('Ты профессиональный Юрист который отвечает на вопросы людей ориентируясь на '
#  'статьи из КоАП РФ\n'
#  'Вот релевантная статья:\n'
#  '<article>\n'
#  'Раздел II. Особенная часть\n'
#  'Глава 12. Административные правонарушения в области дорожного движения\n'
#  'Статья 12.12. Проезд на запрещающий сигнал светофора или на запрещающий жест '
#  'регулировщика\n'
#  '</article>\n'
#  'Вот вопрос:\n'
#  '<query>какой штраф за пересечении стоп-линии красный сигнал '
#  'светофора?</query>\n'
#  '\n'
#  'Ответь нв вопрос, процитировав название статьи, раздел и главу. \n'
#  'Если тебе не дали релевантную статью, попробуй ответить на вопрос, но скажи '
#  'что "релевантная статья не найдена, попробуйте переформулировать вопрос".\n')

# %%
choosed_article[0]
# Out:
# 'Статья 12.12. Проезд на запрещающий сигнал светофора или на запрещающий жест регулировщика'

# %%
# Out:
# '1. Проезд на запрещающий сигнал светофора или на запрещающий жест регулировщика, за исключением случаев, предусмотренных частью\xa01 статьи\xa012.10 настоящего Кодекса и частью\xa02 настоящей статьи, -\nвлечет наложение административного штрафа в размере одной тысячи рублей.\n2. Невыполнение требования Правил дорожного движения об остановке перед стоп-линией, обозначенной дорожными знаками или разметкой проезжей части дороги, при запрещающем сигнале светофора или запрещающем жесте регулировщика -\nвлечет наложение административного штрафа в размере восьмисот рублей.\n3. Повторное совершение административного правонарушения, предусмотренного частью 1 настоящей статьи, -\nвлечет наложение административного штрафа в размере пяти тысяч рублей или лишение права управления транспортными средствами на срок от четырех до шести месяцев.\n\n'

# %%
# Out:
# {'Статья 12.29. Нарушение Правил дорожного движения пешеходом или иным лицом, участвующим в процессе дорожного движения': 'Если ты пешеход или пассажир и нарушаешь правила дорожного движения, то можешь получить штраф в размере 500 рублей. Велосипедисты и другие участники дорожного движения могут получить штраф в 800 рублей, а если они находятся в состоянии опьянения, штраф будет от 1000 до 1500 рублей.',
#  'Статья 12.7. Управление транспортным средством водителем, не имеющим права управления транспортным средством': 'Если ты сядешь за руль без водительских прав, тебе грозит штраф до 15 000 рублей. Если у тебя уже отняли права, и тебя снова поймали за рулем, штраф будет 30 000 рублей, или тебя могут посадить на 15 суток, или заставить работать без оплаты в течение 100-200 часов. И если тебя повторно поймают за рулем без прав, штраф может достигать 100 000 рублей или тебя могут обязать отработать до 200 часов.',
#  'Статья 12.26. Невыполнение водителем транспортного средства требования о прохождении медицинского освидетельствования на состояние опьянения': 'Если тебя попросили пройти медицинское освидетельствование на состояние опьянения и ты за рулем, но не совершил ничего серьезного, отказ может привести к штрафу в 30 000 рублей и лишению прав на срок от полутора до двух лет. Если у тебя вообще нет прав или они были отозваны, то отказ дополнительно может привести к административному аресту на срок до 15 суток или такому же штрафу.',
#  'Статья\xa012.34. Несоблюдение требований по обеспечению безопасности дорожного движения при строительстве, реконструкции, ремонте и\xa0содержании дорог, железнодорожных переездов или других дорожных сооружений': 'Если ты не следишь за безопасностью дорог или не устраняешь препятствия на них, ты можешь получить штраф. Если из-за этого кто-то получит легкую или среднюю травму, твой штраф будет больше. Поэтому важно содержать дороги в хорошем состоянии, чтобы все могли ими безопасно пользоваться.',
#  'Статья 12.21.4. Неисполнение обязанности по внесению платы за проезд транспортного средства по платным автомобильным дорогам, платным участкам автомобильных дорог': 'Если ты едешь по платной дороге и не оплачиваешь проезд, ты можешь получить штраф в размере 1500 рублей. Для грузовиков и автобусов штраф выше - 5000 рублей. Однако если ты оплатишь проезд в течение 20 дней после получения штрафа, наказание отменят.',
#  'Статья 12.30. Нарушение Правил дорожного движения пешеходом или иным участником дорожного движения, повлекшее создание помех в движении транспортных средств либо причинение легкого или средней тяжести вреда здоровью потерпевшего': 'Если ты пешеход или пассажир и своими действиями помешал движению транспорта (например, неожиданно выскочил на дорогу), то тебе могут выписать штраф в размере 1000 рублей. Если же из-за твоих действий кто-то получил легкие или средние травмы, штраф может достигать 1500 рублей. Так что будь внимательным на дороге, чтобы избежать неприятных последствий.',
#  'Статья 12.21.1. Нарушение правил движения тяжеловесного и (или) крупногабаритного транспортного средства': 'Если ты перевозишь груз, превышающий разрешенные габариты или вес, тебя могут оштрафовать. Размер штрафа зависит от того, насколько превышены установленные пределы. За незначительные нарушения (менее 10 сантиметров или 10%) ты заплатишь от 1 000 до 3 000 рублей, а за более серьезные нарушения (более 50 сантиметров или 50%) штраф может достигать 10 000 рублей. Кроме того, если твой грузовик попадет под автоматические камеры, штраф может быть увеличен до 150 000 рублей.',
#  'Статья 12.13. Нарушение правил проезда перекрестков': 'Если ты остановишься на перекрестке или пересечении дорог и загородишь путь другим машинам, которые не могут проехать из-за затора, тебе грозит штраф в 1000 рублей. Также штраф в 1000 рублей можно получить, если ты не уступишь дорогу машине, которая имеет преимущество на перекрестке.',
#  'Статья 12.25. Невыполнение требования о предоставлении транспортного средства или об остановке транспортного средства': 'Если тебя просят остановиться сотрудники полиции, таможни или транспортного надзора, ты обязан выполнить их требование. Если ты не остановишься, тебя могут оштрафовать на 500 рублей. Если ты не остановишься по требованию военных инспекторов, штраф будет от 500 до 800 рублей.',
#  'Статья 12.14. Нарушение правил маневрирования': 'Если ты не подашь знак перед тем, как начать движение, повернуть или остановиться, тебя могут либо предупредить, либо оштрафовать на 500 рублей. Также, если ты не займешь верную полосу перед тем, как повернуть, ты также можешь получить предупреждение или штраф. И последнее, разворачиваться или ехать задним ходом там, где это запрещено, обойдется тебе в 500 рублей.',
#  'Статья 12.35. Незаконное ограничение прав на управление транспортным средством и его эксплуатацию': 'Если полицейский пытается ограничить твои права вождения или пользоваться транспортом без оснований, предусмотренных в законе, или нарушает установленные правила ограничения таких прав, ты можешь привлечь его к ответственности. За это он заплатит штраф в размере 2000 рублей, а если он должностное лицо (например, начальник ГИБДД), то 20 000 рублей.',
#  'Статья 12.18. Непредоставление преимущества в движении пешеходам или иным участникам дорожного движения': 'Согласно закону, если ты управляешь автомобилем, ты обязан уступать дорогу пешеходам, велосипедистам и другим участникам дорожного движения, которые имеют преимущество. Это означает, что если пешеход уже ступил на пешеходный переход или велосипедист едет по предназначенной ему полосе, ты должен остановиться и пропустить их, не создавая помех. За нарушение этого правила тебе грозит штраф от 1500 до 2500 рублей.',
#  'Статья 12.24. Нарушение Правил дорожного движения или правил эксплуатации транспортного средства, повлекшее причинение легкого или средней тяжести вреда здоровью потерпевшего': 'Если ты нарушишь правила дорожного движения и в результате кто-то получит легкие травмы, тебе грозит штраф от 2500 до 5000 рублей или лишение прав на 1-1,5 года. Если травмы окажутся более серьезными, штраф увеличится до 10000-25000 рублей, а срок лишения прав составит 1,5-2 года.',
#  'Статья 12.3. Управление транспортным средством водителем, не имеющим при себе документов, предусмотренных Правилами дорожного движения': 'Если ты управляешь автомобилем без нужных документов (техпаспорт, права, страховка), то можешь получить предупреждение или штраф в 500 рублей. Если же передаешь управление лицу без прав, то штраф будет уже 3000 рублей.',
#  'Статья 12.12. Проезд на запрещающий сигнал светофора или на запрещающий жест регулировщика': 'Молодой человек, если вы проедете на красный свет или проигнорируете указания регулировщика, то вас оштрафуют на 1000 рублей. Если вы не остановитесь перед стоп-линией, когда светофор горит красным или регулировщик указывает остановиться, штраф будет 800 рублей. А если вы повторно нарушите правило, то можете заплатить штраф 5000 рублей или лишиться водительских прав на 4-6 месяцев.',
#  'Статья 12.21.2. Нарушение правил перевозки опасных грузов': 'Перевозка опасных грузов требует специальной подготовки водителя и транспортного средства. Водитель должен иметь необходимые документы и соблюдать все правила безопасности. За нарушение этих требований водители могут лишиться прав на срок от 4 до 6 месяцев или получить штраф от 2000 до 2500 рублей. Должностные лица и юридические лица также несут ответственность в виде штрафов в размере от 15000 до 500000 рублей.',
#  'Статья 12.21.3. Несоблюдение требований законодательства Российской Федерации о внесении платы в счет возмещения вреда, причиняемого автомобильным дорогам общего пользования федерального значения транспортными средствами, имеющими разрешенную максима': 'Если ты управляешь грузовой машиной весом более 12 тонн на федеральных автодорогах и не платишь специальную пошлину, тебя могут оштрафовать на 5 000 рублей. При повторном нарушении штраф увеличивается до 10 000 рублей. Однако если ты только въезжаешь в Россию и проехал без оплаты не более 50 км от границы, ты можешь быть освобожден от штрафа, если сразу внесешь плату.',
#  'Статья 12.9. Превышение установленной скорости движения': 'Если ты превысишь разрешенную скорость на 20-40 км/ч, тебя оштрафуют на 500 рублей. При превышении на 40-60 км/ч штраф от 1000 до 1500 рублей или лишение прав на 4-6 месяцев. За превышение более 80 км/ч придется заплатить 5000 рублей или лишиться прав на 6 месяцев.',
#  'Статья 12.6. Нарушение правил применения ремней безопасности или мотошлемов': 'Перевозить пассажиров и ездить самому нужно пристегнутым ремнем, если в машине есть ремни безопасности. За езду без шлема на мотоцикле или перевозку пассажиров без шлема положен штраф в 1000 рублей.',
#  'Статья 12.33. Повреждение дорог, железнодорожных переездов или других дорожных сооружений': 'Эта статья говорит о том, что если ты повредишь дорогу, переезд или дорожные знаки так, что это создаст опасность для водителей и пешеходов, или умышленно создашь препятствие движению, например, выльешь что-то на дорогу, ты можешь получить штраф. Штраф для обычных людей составит от 5 до 10 тысяч рублей, для должностных лиц - 25 тысяч рублей, а для компаний - 300 тысяч рублей.',
#  'Статья 12.19. Нарушение правил остановки или стоянки транспортных средств': 'Если ты оставишь машину в неположенном месте, тебя могут оштрафовать на 500 рублей. Накажут строже (штраф до 5 000 рублей), если припаркуешься в месте для инвалидов. Также нельзя парковаться на пешеходном переходе, тротуаре, трамвайных путях или ближе 15 метров к остановкам. За такие нарушения штрафы от 1 000 до 3 000 рублей.',
#  'Статья 12.8. Управление транспортным средством водителем, находящимся в состоянии опьянения, передача управления транспортным средством лицу, находящемуся в состоянии опьянения': 'Вождение в пьяном виде может стоить тебе немалых денег (30 000 рублей штрафа) и лишения прав на срок от полутора до двух лет. Более того, если у тебя вообще нет прав или тебя лишили их раньше, за пьяное вождение ты можешь получить срок до 15 суток. Если ты доверишь управление автомобилем пьяному человеку, тебя тоже могут оштрафовать и лишить прав.',
#  'Статья 12.32.1. Допуск к управлению транспортным средством водителя, не имеющего российского национального водительского удостоверения': 'Если руководитель предприятия или иной ответственный человек разрешит управлять транспортом лицу, не имеющему водительских прав (например, при использовании автомобиля компании), ему придется заплатить штраф в размере 50 000 рублей. Это важно помнить, чтобы избежать подобных ситуаций и возможных проблем с законом.',
#  'Статья 12.22. Нарушение правил учебной езды': 'Если человек, который учится водить машину, нарушает правила, то он должен будет заплатить небольшой штраф в размере 500 рублей или получит предупреждение. Это сделано для того, чтобы люди учились водить безопасно и не подвергали опасности себя и других на дороге.',
#  'Статья 12.20. Нарушение правил пользования внешними световыми приборами, звуковыми сигналами, аварийной сигнализацией или знаком аварийной остановки': 'Бен, если ты будешь ездить на машине и неправильно использовать фары, клаксон, аварийку или знак аварийной остановки, тебе могут дать предупреждение или оштрафовать на 500 рублей. Это не очень серьезное наказание, но лучше соблюдать правила, чтобы не создавать аварийные ситуации.',
#  'Статья 12.2. Управление транспортным средством с нарушением правил установки на нем государственных регистрационных знаков': 'Водить машину с неразборчивыми или незаконно установленными номерными знаками карается штрафом в 500 рублей. Если ездить вообще без номеров, на поддельных номерах или с номерами, которые мешают их распознать, то можно потерять права на 1-3 месяца. А если ставить на машину заведомо поддельные номерные знаки, то можно получить штраф до 500 000 рублей или лишиться прав на 6-12 месяцев.',
#  'Статья 12.32. Допуск к управлению транспортным средством водителя, находящегося в состоянии опьянения либо не имеющего права управления транспортным средством': 'Если сотрудник организации позволит водителю управлять автомобилем в нетрезвом состоянии или без водительских прав, то организации грозит штраф в размере ста тысяч рублей. Если же предприниматель без образования юридического лица совершит такое же нарушение, то он будет нести ответственность как юридическое лицо и также заплатит штраф в размере ста тысяч рублей.',
#  'Статья 12.28. Нарушение правил, установленных для движения транспортных средств в жилых зонах': 'Если ты нарушишь правила движения в жилой зоне, например, поедешь слишком быстро или неправильно припаркуешься, тебе придется заплатить штраф в размере 1500 рублей. А если такое нарушение ты совершишь в Москве или Санкт-Петербурге, штраф будет уже 3000 рублей.',
#  'Статья 12.23. Нарушение правил перевозки людей': 'Водители должны соблюдать правила перевозки людей, чтобы обеспечить их безопасность. Если водители нарушают эти правила, такие как перевозка пассажиров вне кабины транспортного средства или нарушение требований к перевозке детей, они будут оштрафованы на сумму до 100 000 рублей. Организованная перевозка групп детей требует строгого соблюдения правил, включая наличие специальных автобусов, квалифицированного водителя и плана маршрута. Нарушение этих требований влечет за собой более высокие штрафы и даже лишение прав водителя.',
#  'Статья 12.5. Управление транспортным средством при наличии неисправностей или условий, при которых эксплуатация транспортных средств запрещена, или транспортным средством, на котором незаконно установлен опознавательный знак "Инвалид"': 'Во-первых, если при управлении транспортом обнаруживаются неисправности (например, с тормозами или рулем), то за это можно получить предупреждение или штраф 500 рублей. Во-вторых, если нет специальной карты, подтверждающей возможность использования транспорта, то штраф составит 2000 рублей. И наконец, если на машине используются запрещенные световые приборы (красные спереди) или светопропускание стекол не соответствует требованиям, то водитель может лишиться прав на срок от полугода до года.',
#  'Статья 12.21. Нарушение правил перевозки грузов, правил буксировки': 'По этой статье наказывают за то, что водитель перевозил грузы или ехал с прицепом, не соблюдая установленные правила. За такое нарушение можно получить предупреждение либо заплатить штраф в размере 500 рублей.',
#  'Статья 12.1. Управление транспортным средством, не зарегистрированным в установленном порядке': 'Если ты ездишь на машине, которая не зарегистрирована должным образом, тебя могут оштрафовать на сумму от 500 до 800 рублей. Если ты сделаешь это снова, заплатишь штраф в размере 5000 рублей или тебе могут запретить управлять автомобилем на срок от месяца до трех. Так что убедись, что твоя машина зарегистрирована, чтобы избежать этих проблем.',
#  'Статья 12.36.1. Нарушение правил пользования телефоном водителем транспортного средства': 'По закону, если водитель пользуется телефоном без специального устройства, позволяющего говорить без рук, во время управления автомобилем, ему грозит штраф в размере 1500 рублей. Это сделано для обеспечения безопасности на дорогах, так как разговор по телефону отвлекает внимание водителя и может привести к авариям.',
#  'Статья 12.15. Нарушение правил расположения транспортного средства на проезжей части дороги, встречного разъезда или обгона': 'Если ты нарушишь правила парковки, проезда или пересечения колонн, не уступишь дорогу тихоходному транспорту, поедешь по тротуару или велодорожке, выедешь на встречную полосу при объезде препятствия, то можешь получить штраф от 1500 до 5000 рублей. И помни, что повторный выезд на встречку повлечет лишение прав на год.',
#  'Статья 12.10. Нарушение правил движения через железнодорожные пути': 'Если ты проезжаешь через железнодорожный переезд с закрытым шлагбаумом или под запрещающий сигнал, или останавливаешься на переезде, ты можешь получить штраф в 5000 рублей или остаться без водительских прав на полгода. За повторное нарушение тебя могут лишить прав на целый год. Так что будь внимателен и не нарушай правила на железной дороге, ведь это может привести к серьезным последствиям.',
#  'Статья 12.27. Невыполнение обязанностей в связи с дорожно-транспортным происшествием': 'Если ты как водитель попадешь в ДТП и не выполнишь правила поведения после него (например, не остановишься, не вызовешь ГИБДД), то тебя могут оштрафовать на 1000 рублей. А если ты после ДТП уедешь с места происшествия или будешь пьян за рулем, то тебя могут лишить прав на срок от года или арестовать.',
#  'Статья 12.37. Несоблюдение требований об обязательном страховании гражданской ответственности владельцев транспортных средств': 'Во-первых, нельзя водить машину без страховки, иначе придется заплатить 800 рублей штрафа. Во-вторых, если у тебя есть страховка, но ты даешь кому-то другому управлять машиной, а он не указан в страховке, то ты заплатишь 500 рублей штрафа. Так что всегда проверяй свою страховку и убеждайся, что она действительна.',
#  'Статья 12.31.1. Нарушение требований обеспечения безопасности перевозок пассажиров и багажа, грузов автомобильным транспортом и городским наземным электрическим транспортом': 'Статья устанавливает ответственность за нарушение правил перевозки пассажиров, багажа и грузов автомобильным и электрическим наземным транспортом. Сотрудники, которые не соответствуют квалификационным требованиям, или перевозят без предрейсового медосмотра или проверки транспорта, подвергаются штрафам. Также наказывают за несоблюдение правил безопасности при перевозке и допуск водителей к работе без необходимого инструктажа.',
#  'Статья\xa012.17.1. Утратила силу': 'Мне нужна статья из кодекса законов, чтобы я мог объяснить ее суть. Без статьи я не могу предоставить объяснение.',
#  'Статья 12.31. Выпуск на линию транспортного средства, не зарегистрированного в установленном порядке, не прошедшего технического осмотра, с заведомо подложными государственными регистрационными знаками, имеющего неисправности, с которыми запрещена эк': 'Выезжать на дорогу на машине без регистрации или техосмотра запрещено. Если обнаружится неисправность, которая запрещает езду, или изменения в машине без разрешения, должностных лиц оштрафуют на 5-8 тысяч рублей. Также запрещено использовать поддельные номера, устанавливать красные световые приборы или мигалки без разрешения, за что придется заплатить штраф до 20 тысяч рублей.',
#  'Статья 12.36. Утратила силу.': 'К сожалению, без предоставления текста статьи я не могу объяснить ее суть. Пожалуйста, предоставьте мне содержание статьи, и я буду рад помочь вам.',
#  'Статья 12.11. Нарушение правил движения по автомагистрали': 'Если ты едешь по скоростной автомагистрали на машине, которая слишком медленная или в плохом состоянии, тебя оштрафуют на 1000 рублей. То же касается остановки на магистрали не в специально отведенных местах. Кроме того, нельзя ездить по второй полосе и дальше на грузовиках тяжелее 3,5 тонн, а также обучаться вождению на магистрали. За это тоже выпишут штраф на 1000 рублей. А если развернешься, въедешь в разрывы разделительной полосы или поедешь задним ходом, заплатишь 2500 рублей.',
#  'Статья 12.4. Нарушение правил установки на транспортном средстве устройств для подачи специальных световых или звуковых сигналов либо незаконное нанесение специальных цветографических схем автомобилей оперативных служб, цветографической схемы легково': 'Если на вашем автомобиле установлены красные фары, мигалки или знаки такси без разрешения, вас могут оштрафовать и конфисковать эти устройства. Также запрещено самовольно наносить на автомобиль спецраскраски, иначе вы получите штраф.',
#  'Статья 12.17. Непредоставление преимущества в движении маршрутному транспортному средству или транспортному средству с включенными специальными световыми и звуковыми сигналами': 'Если не дать дорогу автобусу или машине с синими мигалками и сиреной, ты получишь штраф в 500 рублей. За стоянку или движение на полосе для автобусов без разрешения штраф составляет 1500 рублей, а в Москве и Санкт-Петербурге - 3000 рублей. Если не уступить дорогу машине со спецсигналами (например, полиции или скорой помощи), штраф будет от 3000 до 5000 рублей или же тебя могут лишить прав на срок от трех месяцев до года.',
#  'Статья 12.16. Несоблюдение требований, предписанных дорожными знаками или разметкой проезжей части дороги': 'Если ты не следуешь знакам дорожного движения или разметке, то можешь получить предупреждение или штраф в 500 рублей. Однако, если ты нарушаешь правила поворота, разворота или движения по встречной полосе, то штрафы могут достигать 5000 рублей или даже лишения прав на срок до 6 месяцев. Запрещенные знаки остановки и стоянки грозят штрафом в 1500 рублей, а в Москве и Санкт-Петербурге - в 3000 рублей.'}
